# %%
from drawing_multiplePolicies import DrawingMultiplePolicies
from algorithm import Algorithm
from canvas import Canvas
from rewards import Rewards, Size

# %%
rewards_boards = Rewards().square(size=Size.M)
algorithm = DrawingMultiplePolicies(draw=False, algorithm_kind=Algorithm.POLICY_ITERATION)
canvases = algorithm.create_canvases(rewards_boards, plot=True)
# Out:
# 2024-05-23 00:18:50,378 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:50,379 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:50,383 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 4 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:50,384 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:50,637 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:50,637 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:50,646 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:50,647 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:50,895 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:50,896 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:50,904 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 8 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:50,905 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,183 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,184 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:51,189 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:51,190 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,381 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,382 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:51,386 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 4 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:51,387 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,611 [MainThread] [INFO]  Terminar

# %%
rewards_boards = Rewards().square(size=Size.L)
algorithm = DrawingMultiplePolicies(draw=False, algorithm_kind=Algorithm.POLICY_ITERATION)
canvases = algorithm.create_canvases(rewards_boards, plot=True)
# Out:
# 2024-05-23 00:18:51,622 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:51,623 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:51,871 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:51,872 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:54,369 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:54,369 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:54,740 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 20 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:54,741 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:57,247 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:18:57,248 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:18:57,572 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 20 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:18:57,573 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:00,336 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:00,336 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:19:00,713 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 20 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:19:00,714 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:03,238 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:03,238 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-23 00:19:03,369 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:19:03,369 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:05,835 [MainThread] [INFO]  Terminar

# %%
rewards_board = Rewards().square(size=Size.S, single_trace=True)[0]
canvas = Canvas(rewards_board)
algorithm = DrawingMultiplePolicies(draw=False, algorithm_kind=Algorithm.Q_LEARNING)
canvases = algorithm.create_canvases(rewards_boards, plot=True)

# Visualización de los valores y de de la política
#actions, values = algorithm.actions_values()
#algorithm.canvas.plot_action(actions, values)
# Out:
# 2024-05-23 00:19:05,854 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-23 00:19:05,862 [MainThread] [INFO]  Ejecutando Q_LEARNING para resolver el MDP
# 2024-05-23 00:19:05,994 [MainThread] [INFO]  La ejecución de Q_LEARNING acaba de terminar. 10 fueron necesarias para alcanzar convergencia
# 2024-05-23 00:19:05,995 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2 canvas = Canvas(rewards_board)
#       3 algorithm = DrawingMultiplePolicies(draw=False, algorithm_kind=Algorithm.Q_LEARNING)
# ----> 4 canvases = algorithm.create_canvases(rewards_boards, plot=True)
#       6 # Visualización de los valores y de de la política
#       7 #actions, values = algorithm.actions_values()
#       8 #algorithm.canvas.plot_action(actions, values)
#
# File ~/workspaces/turtle-drawing/proyecto/drawing_multiplePolicies.py:91, in DrawingMultiplePolicies.create_canvases(self, rewards_boards, plot)
#      89     if plot:
#      90         canvas.plot_rainbow()
# ---> 91         canvas.plot_policy(algorithm.policy)
#      92         ##if self.algorithm_kind == Algorithm.Q_LEARNING:
#      93         ##    actions, values = algorithm.actions_values()
#      94         ##    algorithm.canvas.plot_action(actions, values)
#      95         ##else:
#      96         ##    canvas.plot_rainbow()
#      97         ##    canvas.plot_policy(algorithm.policy)
#      99 logger.info("Terminar")
#
# File ~/workspaces/turtle-drawing/proyecto/canvas.py:211, in Canvas.plot_policy(self, policy)
#     209             ax1.text(self.ncols-j-1, self.nrows-i-1, "", ha='center', va='center', fontsize=6)
#     210         else:
# --> 211             ax1.text(j+0.5, self.nrows-i-1+0.5, self.print_policy(i,j, policy), ha='center', va='center', fontsize=6)
#     212 plt.axis("off")
#     213 plt.show()
#
# File ~/workspaces/turtle-drawing/proyecto/canvas.py:161, in Canvas.print_policy(self, i, j, policy)
#     160 def print_policy(self, i, j, policy):
# --> 161     if policy[i][j] == "up":
#     162         return "^"
#     163     elif policy[i][j] == "down":
#
# TypeError: 'NoneType' object is not subscriptable
