# %%
from drawing_multiplePolicies import DrawingMultiplePolicies
from determine_figure import determine_figure
from algorithm import Algorithm

# %%
figure_sequence, dimensions = determine_figure("square 20x20 centered")
algorithm = DrawingMultiplePolicies(figure_sequence, dimensions, draw=False, algorithm_kind=Algorithm.POLICY_ITERATION)
canvases = algorithm.create_canvases(plot=True)
# Out:
# 2024-05-19 21:33:01,070 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,073 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-19 21:33:01,088 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 2 fueron necesarias para alcanzar convergencia
# 2024-05-19 21:33:01,089 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,452 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,453 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-19 21:33:01,476 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 6 fueron necesarias para alcanzar convergencia
# 2024-05-19 21:33:01,477 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,680 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,681 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-19 21:33:01,701 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-19 21:33:01,702 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,982 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:01,983 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-19 21:33:01,997 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 5 fueron necesarias para alcanzar convergencia
# 2024-05-19 21:33:01,998 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:02,477 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:02,478 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-19 21:33:02,484 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 2 fueron necesarias para alcanzar convergencia
# 2024-05-19 21:33:02,485 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-19 21:33:02,706 [MainThread] [INFO]  Terminar
