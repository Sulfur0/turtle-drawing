# %%
from drawing_multiplePolicies import DrawingMultiplePolicies
from algorithm import Algorithm
from canvas import Canvas
from rewards import Rewards, Size

rewards_boards = Rewards().square(size=Size.M)

# %%
algorithm = DrawingMultiplePolicies(draw=False, algorithm_kind=Algorithm.POLICY_ITERATION)
canvases = algorithm.create_canvases(rewards_boards, plot=True)
# Out:
# 2024-05-20 23:23:16,368 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:23:16,369 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-20 23:23:16,373 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 5 fueron necesarias para alcanzar convergencia
# 2024-05-20 23:23:16,374 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:23:16,691 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:23:16,695 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-20 23:23:16,702 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# ...
