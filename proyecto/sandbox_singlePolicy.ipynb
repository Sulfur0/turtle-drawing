# %%
from drawing_singlePolicy import DrawingSinglePolicy
from algorithm import Algorithm
from canvas import Canvas
from rewards import Rewards, Size

rewards_board = Rewards().square(size=Size.M, single_trace=True)[0]

# %%
canvas = Canvas(rewards_board)
algorithm = DrawingSinglePolicy(algorithm_kind=Algorithm.POLICY_ITERATION).train(canvas, plot_policies=False)

# Visualización de los valores y de de la política
algorithm.canvas.plot_rainbow()
algorithm.canvas.plot_policy(algorithm.policy)
# Out:
# 2024-05-20 23:14:41,339 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:14:41,340 [MainThread] [INFO]  Ejecutando POLICY_ITERATION para resolver el MDP
# 2024-05-20 23:14:41,344 [MainThread] [INFO]  La ejecución de POLICY_ITERATION acaba de terminar. 4 fueron necesarias para alcanzar convergencia
# 2024-05-20 23:14:41,344 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...

# %%
canvas = Canvas(rewards_board)
algorithm = DrawingSinglePolicy(algorithm_kind=Algorithm.VALUE_ITERATION).train(canvas, plot_policies=False)

# Visualización de los valores y de de la política
algorithm.canvas.plot_rainbow()
algorithm.canvas.plot_policy(algorithm.policy)
# Out:
# 2024-05-20 23:09:23,293 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:09:23,294 [MainThread] [INFO]  Ejecutando VALUE_ITERATION para resolver el MDP
# 2024-05-20 23:09:23,300 [MainThread] [INFO]  La ejecución de VALUE_ITERATION acaba de terminar. 7 fueron necesarias para alcanzar convergencia
# 2024-05-20 23:09:23,301 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...

# %%
canvas = Canvas(rewards_board)
algorithm = DrawingSinglePolicy(algorithm_kind=Algorithm.MONTE_CARLO).train(canvas, episodes=500, plot_policies=False)

# Visualización de los valores y de de la política
algorithm.canvas.plot_rainbow()
algorithm.canvas.plot_policy(algorithm.policy)
# Out:
# 2024-05-20 23:09:29,141 [MainThread] [INFO]  Inicio del entrenamiento. Calculando la política óptima a partir de las recompensas...
# 2024-05-20 23:09:29,142 [MainThread] [INFO]  Ejecutando MONTE_CARLO para resolver el MDP
# 2024-05-20 23:09:29,382 [MainThread] [INFO]  La ejecución de MONTE_CARLO acaba de terminar. None fueron necesarias para alcanzar convergencia
# 2024-05-20 23:09:29,383 [MainThread] [INFO]  Fin del entrenamiento. Calculando la política óptima a partir de las recompensas...
